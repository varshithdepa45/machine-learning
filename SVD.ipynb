# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler

# Dataset
data = {
    'Math': [90, 85, 78, 92, 70],
    'Science': [85, 80, 75, 88, 65],
    'English': [88, 82, 80, 90, 68]
}

students = ['S1', 'S2', 'S3', 'S4', 'S5']

df = pd.DataFrame(data, index=students)

# Standardize data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(df)

# Apply SVD
U, S, VT = np.linalg.svd(X_scaled)

# Results
print("U Matrix:")
print(U)

print("\nSingular Values:")
print(S)

print("\nV^T Matrix:")
print(VT)

# Visualization of Singular Values
plt.figure(figsize=(8,5))
plt.plot(range(1, len(S)+1), S, marker='o')
plt.title("Singular Values from SVD")
plt.xlabel("Component Number")
plt.ylabel("Singular Value")
plt.grid(True)
plt.show()
# Out:
# U Matrix:
# [[-0.37122539  0.06051419 -0.77617973  0.34317545  0.37189431]
#  [-0.0705557   0.40644469  0.08229002  0.68399373 -0.59599122]
#  [ 0.18982169 -0.85052752  0.04037133  0.4873678  -0.03759572]
#  [-0.50228759  0.06105325  0.62307017  0.29074187  0.52079978]
#  [ 0.75424698  0.32251539  0.03044821  0.30385026  0.48357341]]
#
# Singular Values:
# [3.85726264 0.34198981 0.06758612]
#
# V^T Matrix:
# [[-0.57662493 -0.57949154 -0.57592817]
#  [ 0.66641442  0.07420038 -0.74188013]
#  [-0.47264734  0.81159341 -0.34339573]]
